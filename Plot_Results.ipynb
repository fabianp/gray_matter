# %%
# %pylab inline
import warnings
warnings.filterwarnings('ignore')
import nibabel as nb 
import scipy.io as io
import numpy as np
import glob
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sn
from nilearn import plotting
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Neurological Label time 0

# %%
nifti_neuro1 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster_neuro1_t0.nii'
nifti_neuro2 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster_neuro2_t0.nii'
plotting.plot_stat_map(nifti_neuro1, cut_coords=[-49,-8,-20],draw_cross=False,
                       threshold=0.04, colorbar=False, vmax=0.08,cmap='Blues')
plotting.plot_stat_map(nifti_neuro2,  cut_coords=[-49,-8,-20],draw_cross=False,
                       threshold=0.04, colorbar=False, vmax=0.08,cmap='Reds')
plt.show()

# %% [markdown]
# ### Clustering Label time 0

# %%
nifti_cluster1 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster1_t0.nii'
nifti_cluster2 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster2_t0.nii'
nifti_cluster3 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster3_t0.nii'
plotting.plot_stat_map(nifti_cluster1, cut_coords=[-49,-8,-20], draw_cross=False,
                       threshold=0.04, colorbar=False, vmax=0.08,cmap='Blues')
plotting.plot_stat_map(nifti_cluster2, cut_coords=[-49,-8,-20],  draw_cross=False,
                       threshold=0.04, colorbar=False, vmax=0.08,cmap='Greens')
plotting.plot_stat_map(nifti_cluster3, cut_coords=[-49,-8,-20], draw_cross=False,
                       threshold=0.04, colorbar=False, vmax=0.08,cmap='Reds')
plt.show()

# %% [markdown]
# ### Neurological Label time 1

# %%
nifti_neuro1 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster_neuro1_t1.nii'
nifti_neuro2 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster_neuro2_t1.nii'
plotting.plot_stat_map(nifti_neuro1, cut_coords=[-49,-8,-20],draw_cross=False,
                       threshold=0.04, colorbar=False, vmax=0.08,cmap='Blues')
plotting.plot_stat_map(nifti_neuro2,  cut_coords=[-49,-8,-20],draw_cross=False,
                       threshold=0.04, colorbar=False, vmax=0.08,cmap='Reds')
plt.show()

# %% [markdown]
# ### Clustering Label time 1

# %%
nifti_cluster1 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster1_t1.nii'
nifti_cluster2 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster2_t1.nii'
nifti_cluster3 = '/Users/vborghesani/Desktop/ScienceHack/results/cluster3_t1.nii'
plotting.plot_stat_map(nifti_cluster1, cut_coords=[-49,-8,-20], draw_cross=False,
                       threshold=0.04, colorbar=True, vmax=0.08,cmap='Greens')
plotting.plot_stat_map(nifti_cluster2, cut_coords=[-49,-8,-20],  draw_cross=False,
                       threshold=0.04, colorbar=True, vmax=0.08,cmap='Reds')
plotting.plot_stat_map(nifti_cluster3, cut_coords=[-49,-8,-20], draw_cross=False,
                       threshold=0.04, colorbar=True, vmax=0.08,cmap='Blues')
plt.show()

# %% [markdown]
# ### Most consistently clustered

# %%
nifti_cluster1 = '/Users/vborghesani/Desktop/ScienceHack/results/consistent1.nii'
nifti_cluster2 = '/Users/vborghesani/Desktop/ScienceHack/results/consistent2.nii'
nifti_cluster3 = '/Users/vborghesani/Desktop/ScienceHack/results/consistent3.nii'

plotting.plot_stat_map(nifti_cluster1, cut_coords=[-49,-8,-20], draw_cross=False,
                       threshold=0.04, colorbar=True, vmax=0.08,cmap='Greens')
plotting.plot_stat_map(nifti_cluster2, cut_coords=[-49,-8,-20],  draw_cross=False,
                       threshold=0.04, colorbar=True, vmax=0.08,cmap='Reds')
plotting.plot_stat_map(nifti_cluster3, cut_coords=[-49,-8,-20], draw_cross=False,
                       threshold=0.04, colorbar=True, vmax=0.08,cmap='Blues')
plt.show()
